# %%
# Objectives: 
# 1) Use citipy to extract city names from lon and lat values
# 2) For each of the cities extract weather conditions using api

# %%
# pip install citipy

# %%
# Import libraries and api keys
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from citipy import citipy

# API key for openweathermaps
from api_keys import weather_api_key

# %%
# Generate a list of cities by randomly arranging longitude and latitudes

# Empty lists
lat_lngs = []
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Pull 1500 random samples of lat and lng
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Translate lat and lngs to cities
for i in lat_lngs:
    city = citipy.nearest_city(i[0], i[1]).city_name
    
    # Keep only if city name is unique
    if city not in cities:
        cities.append(city)

# Print count and city names
print(len(cities))
print(cities)
# Out:
# 590
# ['walvis bay', 'port-aux-francais', 'palu', 'longyearbyen', 'waitangi', 'taiohae', 'puerto natales', 'vilyuysk', 'blackmans bay', 'albany', 'zyryanovsk', 'bubaque', 'kasongo-lunda', 'greenville', 'grytviken', 'sao joao da barra', 'west island', 'adamstown', 'constantia', 'mariehamn', 'edinburgh of the seven seas', 'remire-montjoly', 'chui', 'ushuaia', 'belle fourche', 'kilkenny', 'jamestown', 'torghay', 'tres lagoas', 'utrik', 'cadale', 'kotabumi', 'bilibino', 'tromso', 'tanjung pandan', 'baise city', 'mount pearl', 'invercargill', 'kirakira', 'la passe', 'badger', 'pingnan', 'tsiombe', 'zeribet el oued', 'ust-nera', 'port blair', 'iqaluit', 'sao paulo de olivenca', 'alta', 'egilsstadir', 'susuman', 'tiksi', 'ginir', 'hamilton', 'vorgashor', 'bardai', 'lebu', 'autazes', 'aykhal', "ytyk-kyuyel'", 'saldanha', 'ordos', 'mar del plata', 'beteza', 'northam', 'vilyuchinsk', 'punta arenas', 'el porvenir', 'ilulissat', 'olonkinbyen', 'anadyr', 'madimba', 'richards bay', 'hamada', 'labrador city', 'kawthoung', 'papao', 'minas de marcona', 'kununurra', 'axim', 'port macquarie', 'thompson', 'puerto san carlos', 'bethel', 'tazacorte', 'papatowai', 'kalifornsky', 'floro', 'muynoq', 'avarua', 'carnarvon', 'margaret river', 'ponte nova', 'ribeira grande', 'hawaiian paradise park', 'severo-yeniseyskiy', 'iskateley', 'along', 'hermanus', 'copiapo', 'bredasdorp', 'hays', 'armacao de buzios', "hayma'", 'mejit', 'coron', 'haiku-pauwela', 'oranjemund', 'port mathurin', 'keflavik', 'hongwon', 'lihue', 'yangor', 'sao jose da coroa grande', 'whitehaven', 'lorengau', 'aitape', 'aden', 'suva', 'palikir - national government center', 'baltasi', 'mazagao', 'tindouf', 'mozhga', 'qaqortoq', 'stanley', 'newman', 'the bottom', 'puerto ayora', 'happy valley-goose bay', 'guerrero negro', 'puerto carreno', 'colonia', 'katsuren-haebaru', 'micheweni', 'caluula', 'shepton mallet', 'paide', 'nizhniy kuranakh', 'la mira', 'alofi', 'ribas do rio pardo', 'krasnokholm', 'saint-pierre', 'petropavlovsk-kamchatsky', 'kolonia town', 'taguatinga', 'ouellah', 'prince rupert', 'lethem', 'argo', 'nelson bay', 'luganville', 'cill airne', 'port glaud', 'selfoss', 'afaahiti', 'tralee', 'freetown', "port saint john's", 'coari', 'college', 'kapuskasing', 'queenstown', 'sitka', 'kreminna', 'pont rouge', 'nambucca heads', 'las heras', 'hadibu', 'choibalsan', 'undurkhaan', 'georgetown', 'wailua homesteads', 'isafjordur', 'siwa oasis', 'hasaki', 'porto novo', 'kerikeri', 'urumqi', 'pudasjarvi', 'shamakhi', 'sola', 'hoxtolgay', 'pangody', 'rmi capitol', 'hohenlockstedt', 'fale old settlement', 'lata', 'simdega', 'torres', 'kenora', 'palmer', 'soto la marina', 'eirunepe', 'yellowknife', 'aasiaat', 'port lincoln', 'ekibastuz', 'franceville', 'bejubang dua', 'benguela', 'tank', 'fort bragg', 'laguna', 'tura', 'praia da vitoria', 'hithadhoo', 'bikenibeu village', 'fisterra', 'enewetak', 'alexandria', 'bela', 'tongliao', 'talnakh', 'berezovyy', 'ola', 'chatra', 'qamdo', 'laojunmiao', 'eraan', "nikol'sk", 'grand island', 'shahr-e babak', 'kabalo', "nuku'alofa", 'kataragama', 'ancud', 'el kala', 'high rock', 'nushki', 'manokwari', 'kosh-agach', 'wanning', 'harrismith', 'kanniyakumari', 'puerto baquerizo moreno', 'mili', 'east london', 'kattivakkam', 'caleta de carquin', 'el calafate', 'pedro carbo', 'saipan', 'cockburn town', 'portland', 'aldinga beach', 'bamboo flat', 'bokhan', 'waingapu', 'nova sintra', 'tuzlukcu', 'timimoun', 'tra vinh', 'santa terezinha', 'udachny', 'tucurui', 'uturoa', 'vanimo', 'atafu village', 'beli', "st. john's", 'puerto aysen', 'luchow', 'pangyan', 'qaisumah', 'san antonio de pale', 'goure', 'daru', 'saint-philippe', 'kruisfontein', 'mirnyy', 'holmsund', 'vila velha', 'songea', 'irtyshsk', 'cestos city', 'konarka', 'kingston', 'alice springs', 'tamanrasset', 'pariaman', "nar'yan-mar", 'san patricio', 'malmesbury', 'nathdwara', 'koulamoutou', 'cidreira', 'lazaro cardenas', 'pilar', 'port elizabeth', 'quellon', 'scottburgh', 'riviere-du-loup', 'taoudenni', 'toga villag ...

# %%
# Compile weather data using OpenWeatherMap api

# Base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Initialize list
city_data = []

# Create counters
record_count = 1
set_count = 1

# Loop through all cities
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Build url to send request
    city_url = url + "&q=" + city
    
    # Increment count
    record_count += 1

    # For each of the cities
    try:
        # Send request
        city_weather = requests.get(city_url).json()

        # Receive data from api
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append data to list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    # Error handling
    except:
        print("City not found. Skipping...")
        pass
              
print("Done!")
# Out:
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Done!

# %%
# Convert to dataframe
city_data_df = pd.DataFrame(city_data)

print(city_data_df.count())
# Out:
# City          567
# Lat           567
# Lng           567
# Max Temp      567
# Humidity      567
# Cloudiness    567
# Wind Speed    567
# Country       567
# Date          567
# dtype: int64

# %%
# Top five
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         walvis bay -22.9575   14.5053     11.21        94           6
# 1  port-aux-francais -49.3500   70.2167      4.96        95         100
# 2               palu  -0.8917  119.8707     31.72        56          77
# 3       longyearbyen  78.2186   15.6401      5.91       100         100
# 4           waitangi -43.9535 -176.5597      7.68        73          89
#
#    Wind Speed Country        Date
# 0        1.61      NA  1726620199
# 1       12.10      TF  1726620199
# 2        0.35      ID  1726620199
# 3        0.51      SJ  1726620199
# 4        7.15      NZ  1726620199

# %%
# Export to csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read back data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display head
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               walvis bay -22.9575   14.5053     11.21        94           6
# 1        port-aux-francais -49.3500   70.2167      4.96        95         100
# 2                     palu  -0.8917  119.8707     31.72        56          77
# 3             longyearbyen  78.2186   15.6401      5.91       100         100
# 4                 waitangi -43.9535 -176.5597      7.68        73          89
#
#          Wind Speed Country        Date
# City_ID
# 0              1.61     NaN  1726620199
# 1             12.10      TF  1726620199
# 2              0.35      ID  1726620199
# 3              0.51      SJ  1726620199
# 4              7.15      NZ  1726620199

# %%
# Associate Latitude and temperature

plt.scatter(     
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Cities"
)

# Augment
plt.title("City Max Latitude vs. Temperature (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save 
plt.savefig("Temp_vs_Lat.png")

# Show plot
plt.show()

# %%
# Associate Latitude and humidity

plt.scatter(     
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Cities"
)

# Augment
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save
plt.savefig("Humidity_vs_Lat.png")

# Show plot
plt.show()

# %%
# Associate Latitude and cloudiness

plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Cities"
)

# Augment
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save 
plt.savefig("Cloudiness_vs_Lat.png")

# Show plot
plt.show()

# %%
# Associate Latitude and wind speed

plt.scatter(
    city_data_df["Lat"], 
    city_data_df["Wind Speed"],
    edgecolor="black", 
    linewidths=1, 
    marker="o", 
    alpha=0.8,
    label="Cities"
)

# Augment
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%Y-%m-%d"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save
plt.savefig("Windspeed_vs_Lat.png")

# Show plot
plt.show()

# %%
# Regression analysis for each of the pairs above.

# Define a function
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0),:]

northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3        longyearbyen  78.2186   15.6401      5.91       100         100
# 6            vilyuysk  63.7553  121.6247      3.54        89         100
# 8              albany  42.6001  -73.9662     19.70        65         100
# 9          zyryanovsk  49.7386   84.2719      0.92        68           0
# 10            bubaque  11.2833  -15.8333     26.84        83         100
#
#          Wind Speed Country        Date
# City_ID
# 3              0.51      SJ  1726620199
# 6              3.56      RU  1726620199
# 8              1.02      US  1726619911
# 9              1.33      KZ  1726620199
# 10             7.51      GW  1726620199

# %%
# Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0),:]

southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               walvis bay -22.9575   14.5053     11.21        94           6
# 1        port-aux-francais -49.3500   70.2167      4.96        95         100
# 2                     palu  -0.8917  119.8707     31.72        56          77
# 4                 waitangi -43.9535 -176.5597      7.68        73          89
# 5           puerto natales -51.7236  -72.4875     -0.06        89          18
#
#          Wind Speed Country        Date
# City_ID
# 0              1.61     NaN  1726620199
# 1             12.10      TF  1726620199
# 2              0.35      ID  1726620199
# 4              7.15      NZ  1726620199
# 5              1.57      CL  1726620199

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (6,-10))
# Out:
# The r-value is: 0.630059287165639

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-55, 35))
# Out:
# The r-value is: 0.6446068433523616

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity",(40,10))
# Out:
# The r-value is: 0.00015262969732907542

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (-50, 20))
# Out:
# The r-value is: 0.007652339225944964

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (40,10))
# Out:
# The r-value is: 0.01651237079895849

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (-30,30))
# Out:
# The r-value is: 0.0013897001599228645

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (10,12))
# Out:
# The r-value is: 0.0001617292837835694

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-50, 12))
# Out:
# The r-value is: 0.09503043068490429
